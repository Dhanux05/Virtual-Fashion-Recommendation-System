# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 import pickle
# ----> 2 pickle.dump(model, open("model.PK1", "wb"))
#
# NameError: name 'model' is not defined
